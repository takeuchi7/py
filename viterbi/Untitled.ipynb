# %%
# -*- coding:utf-8 -*-

states = ("rainy","sunny")
observations = ("walk","shop","clean","shop","walk")
start_prob = {"rainy":0.6,"sunny":0.4}
transit_prob = {"rainy":{"rainy":0.7,"sunny":0.3},
                "sunny":{"rainy":0.4,"sunny":0.6}}
emission_prob = {'rainy' : {'walk': 0.1, 'shop': 0.4, 'clean': 0.5},
                 'sunny' : {'walk': 0.6, 'shop': 0.3, 'clean': 0.1}}

def viterbi(observs,states,sp,tp,ep):
    """viterbi algorithm
    Output : labels estimated"""
    T = {} # present state
    for st in states:#("rainy","sunny")の２ループ
        print('st',st,sp[st],ep[st][observs[0]])
        T[st] = (sp[st]*ep[st][observs[0]],[st])
        print('T[st]',T[st])
        #st rainy 0.6 0.1
        #T[st] (0.06, ['rainy'])
        #st sunny 0.4 0.6
        #T[st] (0.24, ['sunny'])
        
    for ob in observs[1:]:
        #"shop","clean","shop","walk"の4ループ
        print('ob',ob)
        T = next_state(ob,states,T,tp,ep)
        print('T',T)
    prob,labels = max([T[st] for st in T])
    return prob,labels


def next_state(ob,states,T,tp,ep):
    """calculate a next state's probability, and get a next path"""
    U = {} # next state
    for next_s in states:#("rainy","sunny")の２ループ
        U[next_s] = (0,[])
        for now_s in states:#("rainy","sunny")の２ループ
            p = T[now_s][0] * tp[now_s][next_s] * ep[next_s][ob]
            print('p',p,T[now_s][0] , tp[now_s][next_s] , ep[next_s][ob])
            if p>U[next_s][0]:
                U[next_s] = [p,T[now_s][1]+[next_s]]
                print('UU',U[next_s])
    print('U',U)
    return U

if __name__=="__main__":
    print(observations)
    a,b = viterbi(observations,states,
                  start_prob,transit_prob,emission_prob)
    print(b)
    print(a)
# Out:
# ('walk', 'shop', 'clean', 'shop', 'walk')
# st rainy 0.6 0.1
# T[st] (0.06, ['rainy'])
# st sunny 0.4 0.6
# T[st] (0.24, ['sunny'])
# ob shop
# p 0.0168 0.06 0.7 0.4
# UU [0.0168, ['rainy', 'rainy']]
# p 0.038400000000000004 0.24 0.4 0.4
# UU [0.038400000000000004, ['sunny', 'rainy']]
# p 0.005399999999999999 0.06 0.3 0.3
# UU [0.005399999999999999, ['rainy', 'sunny']]
# p 0.043199999999999995 0.24 0.6 0.3
# UU [0.043199999999999995, ['sunny', 'sunny']]
# U {'rainy': [0.038400000000000004, ['sunny', 'rainy']], 'sunny': [0.043199999999999995, ['sunny', 'sunny']]}
# T {'rainy': [0.038400000000000004, ['sunny', 'rainy']], 'sunny': [0.043199999999999995, ['sunny', 'sunny']]}
# ob clean
# p 0.01344 0.038400000000000004 0.7 0.5
# UU [0.01344, ['sunny', 'rainy', 'rainy']]
# p 0.00864 0.043199999999999995 0.4 0.5
# p 0.001152 0.038400000000000004 0.3 0.1
# UU [0.001152, ['sunny', 'rainy', 'sunny']]
# p 0.0025919999999999997 0.043199999999999995 0.6 0.1
# UU [0.0025919999999999997, ['sunny', 'sunny', 'sunny']]
# U {'rainy': [0.01344, ['sunny', 'rainy', 'rainy']], 'sunny': [0.0025919999999999997, ['sunny', 'sunny', 'sunny']]}
# T {'rainy': [0.01344, ['sunny', 'rainy', 'rainy']], 'sunny': [0.0025919999999999997, ['sunny', 'sunny', 'sunny']]}
# ob shop
# p 0.0037632 0.01344 0.7 0.4
# UU [0.0037632, ['sunny', 'rainy', 'rainy', 'rainy']]
# p 0.00041471999999999993 0.0025919999999999997 0.4 0.4
# p 0.0012096 0.01344 0.3 0.3
# UU [0.0012096, ['sunny', 'rainy', 'rainy', 'sunny']]
# p 0.0004665599999999999 0.0025919999999999997 0.6 0.3
# U {'rainy': [0.0037632, ['sunny', 'rainy', 'rainy', 'rainy']], 'sunny': [0.0012096, ['sunny', 'rainy', 'rainy', 'sunny']]}
# T {'rainy': [0.0037632, ['sunny', 'rainy', 'rainy', 'rainy']], 'sunny': [0.0012096, ['sunny', 'rainy', 'rainy', 'sunny']]}
# ob walk
# p 0.000263424 0.0037632 0.7 0.1
# UU [0.000263424, ['sunny', 'rainy', 'rainy', 'rainy', 'rainy']]
# p 4.8384e-05 0.0012096 0.4 0.1
# p 0.000677376 0.0037632 0.3 0.6
# UU [0.000677376, ['sunny', 'rainy', 'rainy', 'rainy', 'sunny']]
# p 0.0004354559999999999 0.0012096 0.6 0.6
# U {'rainy': [0.000263424, ['sunny', 'rainy', 'rainy', 'rainy', 'rainy']], 'sunny': [0.000677376, ['sunny', 'rainy', 'rainy', 'rainy', 'sunny']]}
# T {'rainy': [0.000263424, ['sunny', 'rainy', 'rainy', 'rainy', 'rainy']], 'sunny': [0.000677376, ['sunny', 'rainy', 'rainy', 'rainy', 'sunny']]}
# ['sunny', 'rainy', 'rainy', 'rainy', 'sunny']
# 0.000677376
